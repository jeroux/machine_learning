# %% [markdown]
# ## Exercise 3
# * **Dataset:** [`Red wine`](https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009)
# * **Model to use:** [`Decision tree`](https://scikit-learn.org/stable/modules/tree.html)
# * **Model evaluation:** You can choose.

# %%
# Add you code here.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate

# %%
data = pd.read_csv("winequality-red.csv")
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
X = data.drop('quality', axis=1)
y = data['quality']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Declare an instance of it
classifier = DecisionTreeClassifier()
# Fit the model
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(classifier.score(X_test, y_test))
print(classification_report(y_test,classifier.predict(X_test)))
# Out:
# 0.5770833333333333
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        17
#            5       0.65      0.66      0.65       195
#            6       0.57      0.58      0.58       200
#            7       0.47      0.49      0.48        61
#            8       0.50      0.33      0.40         6
#
#     accuracy                           0.58       480
#    macro avg       0.37      0.34      0.35       480
# weighted avg       0.57      0.58      0.57       480

# %%
model = classifier
y_proba = classifier.predict_proba(X_test)
classes = model.classes_

plt.figure(figsize=(15, 12))
for i in range(0, len(classes)):
    fpr, tpr, _ = roc_curve([1 if n == classes[i] else 0 for n in y_test], y_proba[:, i])    
    plt.plot(fpr, tpr, label=classes[i])
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Receiver Operating Characteristic (ROC) curve')
    plt.legend(loc="lower right", title='Pred. Class')
plt.show()

# %%
scoring = ['roc_auc_ovr', 'roc_auc_ovo']
cv_score = cross_validate(model, X_train, y_train, cv=5, scoring=scoring)
base_test_roc_auc_ovr = cv_score['test_roc_auc_ovr'].mean()
base_test_roc_auc_ovo = cv_score['test_roc_auc_ovo'].mean()

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

params = {'min_samples_split': randint(2, 5),
         'min_samples_leaf': randint(1, 5)}
grid = RandomizedSearchCV(model,
                          params,
                          scoring=scoring,
                          refit='roc_auc_ovr',
                          cv=5,
                          n_iter=100,
                          n_jobs=-1)
_ = grid.fit(X_train, y_train)

# %%
print(f"Score of {grid.best_score_*100:.2f}% with {grid.best_params_}")
# Out:
# Score of 64.14% with {'min_samples_leaf': 4, 'min_samples_split': 2}

# %%
grid_score = cross_validate(grid.best_estimator_, X_train, y_train, cv=5, scoring=scoring)
grid_test_roc_auc_ovr = grid_score['test_roc_auc_ovr'].mean()
grid_test_roc_auc_ovo = grid_score['test_roc_auc_ovo'].mean()
for score in scoring:
    print(score[-3:], ':')
    print(f"   base_test_{score}:", eval(f"base_test_{score}"))
    print(f"   grid_test_{score}:", eval(f"grid_test_{score}"))
    print(f"   improved by:",(eval(f"grid_test_{score}") - eval(f"base_test_{score}")) * 100,'%')
# Out:
# ovr :
#    base_test_roc_auc_ovr: 0.6068188315354134
#    grid_test_roc_auc_ovr: 0.6209736811109516
#    improved by: 1.4154849575538253 %
# ovo :
#    base_test_roc_auc_ovo: 0.591459952978667
#    grid_test_roc_auc_ovo: 0.6022113641618587
#    improved by: 1.0751411183191673 %
